# %% [markdown]
# Take synthetic rho data and attempt outlier detection with one other type of a synthetic lightcurve; sine, flat, box function, inverted rho etc (an obvious outlier).

# %%
import os
import fnmatch
import csv
import numpy as np
import sys
sys.stdout.flush()
import math

from collections import Counter

from sklearn import tree


import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

import segment_cluster as sc
import importlib
importlib.reload(sc)


np.random.seed(0)

# %%
#"normal" lightcurves
rho_file=np.loadtxt("synthetic_rhos.csv", delimiter=',')
#"outlier" lightcurves
sine_file=np.loadtxt("synthetic_sines.csv", delimiter=',')

# %%
rho_train, rho_valid, rho_train_ids, rho_valid_ids= train_test_split(rho_file, list(range(len(rho_file))) ,test_size=0.25)

# %%
reco_error=[]
#reco_classes=[]
k_clusters=[10, 50, 100]
seg_lens=[4,8,12,30,50,100]

for k_id, k_cluster in enumerate(k_clusters):
    for len_id, seg_len in enumerate(seg_lens):
        ##train the model
        #loop throught the light curves of a given class and segments them
        all_train_segments=[]
        for rho in rho_train:
            train_segments=sc.segmentation(rho, seg_len, seg_len, time_stamps=False)
            all_train_segments.append(train_segments)
        all_train_segments=np.vstack(all_train_segments)
        #cluster the segments
        cluster=KMeans(n_clusters=k_cluster, random_state=0)
        cluster.fit(all_train_segments)

        ### reconstruction of the training class
        for n_rho, rho in enumerate(rho_valid):
            valid_segments= sc.segmentation(rho, seg_len, seg_len , time_stamps=False)
            reco = sc.reconstruct(valid_segments, rho, cluster, rel_offset=False, seg_slide=seg_len)
            error=np.sqrt(np.mean((rho[seg_len:-seg_len]-reco[seg_len:-seg_len])**2))
            reco_error.append((k_id,len_id,0, n_rho, error))
            print((k_id,len_id,0, n_rho, error), flush=True)


        #reconstruction loop through light curves for every class other than rho              
        for n_sine, sine in enumerate(sine_file):
            valid_segments= sc.segmentation(sine, seg_len, seg_len , time_stamps=False)
            reco = sc.reconstruct(valid_segments, sine, cluster, rel_offset=False, seg_slide=seg_len)
            error=np.sqrt(np.mean((sine[seg_len:-seg_len]-reco[seg_len:-seg_len])**2))
            reco_error.append((k_id,len_id,1,n_sine, error))
            print((k_id,len_id,1,n_sine, error), flush=True)
reco_error_ar=np.array(reco_error)
np.savetxt("valid_results_20190509.csv", reco_error_ar, delimiter=",")
# Out:
# (0, 0, 0, 0, 342.62018245156406)
# (0, 0, 1, 0, 249.31751821844298)
# (0, 0, 1, 1, 258.8310251998609)
# (0, 0, 1, 2, 250.06104385816252)
# (0, 0, 1, 3, 250.00189319329803)
# (0, 0, 1, 4, 270.5024688389461)
# (0, 0, 1, 5, 271.9493939842887)
# (0, 0, 1, 6, 265.2026089815642)
# (0, 0, 1, 7, 244.29957578073484)
# (0, 0, 1, 8, 254.63831648860136)
# (0, 0, 1, 9, 269.2810516376172)
# (0, 0, 1, 10, 280.14217215074575)
# (0, 0, 1, 11, 260.25812395506733)
# (0, 0, 1, 12, 277.04883278912104)
# (0, 0, 1, 13, 276.02605229956515)
# (0, 0, 1, 14, 326.17681567676846)
# (0, 0, 1, 15, 286.196465055262)
# (0, 0, 1, 16, 259.10665208491974)
# (0, 0, 1, 17, 264.96316279114774)
# (0, 0, 1, 18, 262.2468296239352)
# (0, 0, 1, 19, 254.3397899314815)
# (0, 0, 1, 20, 278.16099431033615)
# (0, 0, 1, 21, 267.6540352540229)
# (0, 0, 1, 22, 278.1974469668898)
# (0, 0, 1, 23, 280.79804548983503)
# (0, 0, 1, 24, 288.97859655848345)
# (0, 0, 1, 25, 255.588521069423)
# (0, 0, 1, 26, 310.9912377604033)
# (0, 0, 1, 27, 270.1529240273794)
# (0, 0, 1, 28, 291.5751898330347)
# (0, 0, 1, 29, 302.6050536574784)
# (0, 0, 1, 30, 244.8170984001919)
# (0, 0, 1, 31, 269.5191618489455)
# (0, 0, 1, 32, 237.84057811985625)
# (0, 0, 1, 173, 301.2873394370936)
# (0, 0, 1, 174, 290.4502555331973)
# (0, 0, 1, 175, 297.77893793471225)
# (0, 0, 1, 176, 266.89211982808405)
# (0, 0, 1, 177, 277.0414251952565)
# (0, 0, 1, 178, 294.281601315818)
# (0, 0, 1, 179, 260.0944548871436)
# (0, 0, 1, 180, 260.3272826667471)
# (0, 0, 1, 181, 276.9259533354951)
# (0, 0, 1, 182, 277.66972551706704)
# (0, 0, 1, 183, 284.2753404647785)
# (0, 0, 1, 184, 258.76789028065593)
# (0, 0, 1, 185, 265.63479940223203)
# (0, 0, 1, 186, 275.9140762093314)
# (0, 0, 1, 187, 260.44442725528035)
# (0, 0, 1, 188, 241.31893552567746)
# (0, 0, 1, 189, 271.92359481538347)
# (0, 0, 1, 190, 250.64775399750616)
# (0, 0, 1, 191, 239.22284189932705)
# (0, 0, 1, 192, 252.44894337546617)
# (0, 0, 1, 193, 253.02068654509836)
# (0, 0, 1, 194, 267.23712341352336)
# (0, 0, 1, 195, 297.11677939079243)
# (0, 0, 1, 196, 274.85420876921864)
# (0, 0, 1, 197, 309.3396006945023)
# (0, 0, 1, 198, 296.09878934180955)
# (0, 0, 1, 199, 285.88339318494576)
# (0, 0, 1, 200, 256.38527242170574)
# (0, 0, 1, 201, 252.94846904237113)
# (0, 0, 1, 202, 257.00481527563124)
# (0, 0, 1, 203, 254.5744106962511)
# (0, 0, 1, 204, 243.00128179189738)
# (0, 0, 1, 205, 269.62195217923494)
# (0, 0, 1, 206, 253.37993483560535)
# (0, 0, 1, 207, 317.20460332445697)
# (0, 0, 1, 208, 296.96825704533035)
# (0, 0, 1, 209, 272.1533865921674)
# (0, 0, 1, 210, 261.81461951268983)
# (0, 0, 1, 211, 362.13758185460284)
# (0, 0, 1, 212, 293.97174386504145)
# (0, 0, 1, 213, 267.2724590903865)
# (0, 0, 1, 214, 301.29825516466957)
# (0, 0, 1, 215, 259.5768818402847)
# (0, 0, 1, 216, 266.90083307110285)
# (0, 0, 1, 217, 252.0026865396337)
# (0, 0, 1, 218, 250.04208650620794)
# (0, 0, 1, 219, 290.2929042453735)
# (0, 0, 1, 220, 272.71806115854037)
# (0, 0, 1, 221, 314.04080374455873)
# (0, 0, 1, 222, 251.77118394857715)
# (0, 0, 1, 223, 274.20324661037733)
# (0, 0, 1, 224, 249.84567951695394)
# (0, 0, 1, 225, 274.2728216520469)
# (0, 0, 1, 226, 270.7698169318481)
# (0, 0, 1, 227, 309.66767618613136)
# (0, 0, 1, 228, 281.57148757036)
# (0, 0, 1, 229, 237.87672567970154)
# (0, 0, 1, 230, 245.23101060526332)
# (0, 0, 1, 231, 259.5854572026127)
# (0, 0, 1, 232, 270.2194539373404)
# (0, 0, 1, 233, 247.95238106192045)
# (0, 0, 1, 234, 243.49157767194794)
# (0, 0, 1, 235, 279.79053607190303)
# (0, 0, 1, 236, 304.44039360069746)
# (0, 0, 1, 237, 229.92185276309883)
# (0, 0, 1, 238, 272.66653157050155)
# (0, 0, 1, 239, 267.89933224092516)
# (0, 0, 1, 240, 270.39005406448763)
# (0, 0, 1, 241, 246.67053502893683)
# (0, 0, 1, 242, 299.99826898305224)
# (0, 0, 1, 243, 276.53828625528877)
# (0, 0, 1, 244, 270.5762079984529)
# (0, 0, 1, 245, 243.0669465630847)
# (0, 0, 1, 246, 263.9496637098115)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ebc840b7fb7d> in <module>()
#      30         for n_sine, sine in enumerate(sine_file):
#      31             valid_segments= sc.segmentation(sine, seg_len, seg_len , time_stamps=False)
# ---> 32             reco = sc.reconstruct(valid_segments, sine, cluster, rel_offset=False, seg_slide=seg_len)
#      33             error=np.sqrt(np.mean((sine[seg_len:-seg_len]-reco[seg_len:-seg_len])**2))
#      34             reco_error.append((k_id,len_id,1,n_sine, error))
#
# ~/Documents/timeseries_segment_clustering/segment_cluster.py in reconstruct(test_segments, test_ts, kmeans_model, rel_offset, seg_slide)
#      90         reco= np.zeros(len(test_ts))
#      91         for n_seg, segment in enumerate(test_segments):
# ---> 92             pred_centroid_index=kmeans_model.predict(np.array(segment).reshape(1, -1))[0]
#      93             pred_centroid=centroids[pred_centroid_index]
#      94
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in predict(self, X, sample_weight)
#    1077         x_squared_norms = row_norms(X, squared=True)
#    1078         return _labels_inertia(X, sample_weight, x_squared_norms,
# -> 1079                                self.cluster_centers_)[0]
#    1080
#    1081     def score(self, X, y=None, sample_weight=None):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _labels_inertia(X, sample_weight, x_squared_norms, centers, precompute_distances, distances)
#     682             return _labels_inertia_precompute_dense(X, sample_weight,
#     683                                                     x_squared_norms, centers,
# --> 684                                                     distances)
#     685         inertia = _k_means._assign_labels_array(
#     686             X, sample_weight, x_squared_norms, centers, labels,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _labels_inertia_precompute_dense(X, sample_weight, x_squared_norms, centers, distances)
#     619     # TODO: Once PR #7383 is merged use check_inputs=False in metric_kwargs.
#     620     labels, mindist = pairwise_distances_argmin_min(
# --> 621         X=X, Y=centers, metric='euclidean', metric_kwargs={'squared': True})
#     622     # cython k-means code assumes int32 inputs
#     623     labels = labels.astype(np.int32)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_argmin_min(X, Y, axis, metric, batch_size, metric_kwargs)
#     354     indices, values = zip(*pairwise_distances_chunked(
#     355         X, Y, reduce_func=_argmin_min_reduce, metric=metric,
# --> 356         **metric_kwargs))
#     357     indices = np.concatenate(indices)
#     358     values = np.concatenate(values)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1310             chunk_size = D_chunk.shape[0]
#    1311             D_chunk = reduce_func(D_chunk, sl.start)
# -> 1312             _check_chunk_size(D_chunk, chunk_size)
#    1313         yield D_chunk
#    1314
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _check_chunk_size(reduced, chunk_size)
#    1127                         'Expected sequence(s) of length %d.' %
#    1128                         (reduced if is_tuple else reduced[0], chunk_size))
# -> 1129     if any(_num_samples(r) != chunk_size for r in reduced):
#    1130         # XXX: we use int(_num_samples...) because sometimes _num_samples
#    1131         #      returns a long in Python 2, even for small numbers.
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in <genexpr>(.0)
#    1127                         'Expected sequence(s) of length %d.' %
#    1128                         (reduced if is_tuple else reduced[0], chunk_size))
# -> 1129     if any(_num_samples(r) != chunk_size for r in reduced):
#    1130         # XXX: we use int(_num_samples...) because sometimes _num_samples
#    1131         #      returns a long in Python 2, even for small numbers.
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     143         # Check that shape is returning an integer or default to len
#     144         # Dask dataframes may not return numeric shape[0] value
# --> 145         if isinstance(x.shape[0], numbers.Integral):
#     146             return x.shape[0]
#     147         else:
#
# ~/anaconda3/lib/python3.6/abc.py in __instancecheck__(cls, instance)
#     178                 print("%s: %r" % (name, value), file=file)
#     179
# --> 180     def __instancecheck__(cls, instance):
#     181         """Override for isinstance(instance, cls)."""
#     182         # Inline the cache checking
#
# KeyboardInterrupt:
